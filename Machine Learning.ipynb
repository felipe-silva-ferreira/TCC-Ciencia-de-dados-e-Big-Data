# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import os

# %%
os.chdir(r'C:\Users\Felipe\OneDrive - AGU\Certificados - cursos\Cursos - arquivos\PUC Minas\TCC\Base de dados - TSE candidatos')

df = pd.read_parquet('df_final.parquet')
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882570 entries, 0 to 882569
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   SG_UF                    882570 non-null  object
#  1   DS_CARGO                 882570 non-null  object
#  2   DS_SITUACAO_CANDIDATURA  882570 non-null  object
#  3   TP_AGREMIACAO            882570 non-null  object
#  4   SG_PARTIDO               882570 non-null  object
#  5   DS_GENERO                882570 non-null  object
#  6   DS_GRAU_INSTRUCAO        882570 non-null  object
#  7   DS_ESTADO_CIVIL          882570 non-null  object
#  8   DS_COR_RACA              882570 non-null  object
#  9   DS_OCUPACAO              882570 non-null  object
#  10  ST_REELEICAO             882570 non-null  object
#  11  ST_DECLARAR_BENS         882570 non-null  object
#  12  devedor                  882570 non-null  int32
# ...

# %%
df_codificado = pd.get_dummies(df)

# %%
df_codificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882570 entries, 0 to 882569
# Columns: 374 entries, devedor to Faixa_despesa_Gastão
# dtypes: int32(1), uint8(373)
# memory usage: 317.3 MB

# %%
# Dividir os dados entre classes majoritárias e minoritárias:
maioria = df_codificado[df_codificado['devedor'] == 0]
minoria = df_codificado[df_codificado['devedor'] == 1]
# Subamostrar a classe majoritária:
majority_downsampled = maioria.sample(n=len(minoria), random_state=42)
# Combinar as classes subamostradas e minoritárias e misturá-las:
downsampled = pd.concat([majority_downsampled, minoria])
downsampled = downsampled.sample(frac=1, random_state=42)

# %%
X = df_codificado.drop('devedor', axis=1)
y = df_codificado['devedor']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
# Treinar o Modelo:
clf = RandomForestClassifier(class_weight='balanced')
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 clf = RandomForestClassifier(class_weight='balanced')
# ----> 2 clf.fit(X_train, y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:473, in BaseForest.fit(self, X, y, sample_weight)
#     462 trees = [
#     463     self._make_estimator(append=False, random_state=random_state)
#     464     for i in range(n_more_estimators)
#     465 ]
#     467 # Parallel loop: we prefer the threading backend as the Cython code
#     468 # for fitting the trees is internally releasing the Python GIL
#     469 # making threading more efficient than multiprocessing in
#     470 # that case. However, for joblib 0.12+ we respect any
#     471 # parallel_backend contexts set at a higher level,
#     472 # since correctness does not rely on using threads.
# --> 473 trees = Parallel(
# ...

# %%
# Cria e avalia o modelo KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(X_train.values, y_train)
score = model.score(X_test.values, y_test)

# %%
# Cria e avalia o modelo Gaussian Naive Bayes
model = GaussianNB()
model.fit(X_train, y_train)
score = model.score(X_test, y_test)

# %%
# Cria e avalia o modelo Decision Tree Classifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
score = model.score(X_test, y_test)

# %%
# Cria e avalia o modelo Support Vector Classifier
model = SVC()
model.fit(X_train, y_train)
score = model.score(X_test, y_test)
