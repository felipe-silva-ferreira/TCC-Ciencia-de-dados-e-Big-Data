# %%
import os
import pyarrow
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Definindo o diretório de trabalho
os.chdir(r'C:\Users\Felipe\OneDrive - AGU\Certificados - cursos\Cursos - arquivos\PUC Minas\TCC\Base de dados - TSE candidatos')

# %%
# Lendo os arquivos parquet
df_tse = pd.read_parquet('df_tse.parquet')
df_sapiens = pd.read_parquet('df_sapiens.parquet')

# %% [markdown]
# ### 1.1 Tratando os dados do tse

# %%
# Exibindo informações iniciais sobre df_tse
df_tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115624 entries, 0 to 1115623
# Data columns (total 75 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   DT_GERACAO                     1115624 non-null  object
#  1   HH_GERACAO                     1115624 non-null  object
#  2   ANO_ELEICAO                    1115624 non-null  object
#  3   CD_TIPO_ELEICAO                1115624 non-null  object
#  4   NM_TIPO_ELEICAO                1115624 non-null  object
#  5   NR_TURNO                       1115624 non-null  object
#  6   CD_ELEICAO                     1115624 non-null  object
#  7   DS_ELEICAO                     1115624 non-null  object
#  8   DT_ELEICAO                     1115624 non-null  object
#  9   TP_ABRANGENCIA                 1115624 non-null  object
#  10  SG_UF                          1115624 non-null  object
#  11  SG_UE                          1115624 non-null  object
#  12  NM_UE                          1115624 non-null  object
#  13  CD_CARGO                       1115624 non-null  object
#  14  DS_CARGO                       1115624 non-null  object
#  15  SQ_CANDIDATO                   1115624 non-null  object
#  16  NR_CANDIDATO                   1115624 non-null  object
#  17  NM_CANDIDATO                   1115624 non-null  object
#  18  NM_URNA_CANDIDATO              1115624 non-null  object
#  19  NM_SOCIAL_CANDIDATO            1115624 non-null  object
#  20  NR_CPF_CANDIDATO               1115624 non-null  object
#  21  NM_EMAIL                       1115624 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        1115624 non-null  object
#  23  DS_SITUACAO_CANDIDATURA        1115624 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       1115624 non-null  object
#  25  DS_DETALHE_SITUACAO_CAND       1115624 non-null  object
#  26  TP_AGREMIACAO                  1115624 non-null  object
#  27  NR_PARTIDO                     1115624 non-null  object
#  28  SG_PARTIDO                     1115624 non-null  object
#  29  NM_PARTIDO                     1115624 non-null  object
#  30  NR_FEDERACAO                   1115624 non-null  object
#  31  NM_FEDERACAO                   1115624 non-null  object
#  32  SG_FEDERACAO                   1115624 non-null  object
#  33  DS_COMPOSICAO_FEDERACAO        1115624 non-null  object
#  34  SQ_COLIGACAO                   1115624 non-null  object
#  35  NM_COLIGACAO                   1115624 non-null  object
#  36  DS_COMPOSICAO_COLIGACAO        1115624 non-null  object
#  37  CD_NACIONALIDADE               1115624 non-null  object
#  38  DS_NACIONALIDADE               1115624 non-null  object
#  39  SG_UF_NASCIMENTO               1115624 non-null  object
#  40  CD_MUNICIPIO_NASCIMENTO        1115624 non-null  object
#  41  NM_MUNICIPIO_NASCIMENTO        1115624 non-null  object
#  42  DT_NASCIMENTO                  1115624 non-null  object
#  43  NR_IDADE_DATA_POSSE            1115624 non-null  object
#  44  NR_TITULO_ELEITORAL_CANDIDATO  1115624 non-null  object
#  45  CD_GENERO                      1115624 non-null  object
#  46  DS_GENERO                      1115624 non-null  object
#  47  CD_GRAU_INSTRUCAO              1115624 non-null  object
#  48  DS_GRAU_INSTRUCAO              1115624 non-null  object
#  49  CD_ESTADO_CIVIL                1115624 non-null  object
#  50  DS_ESTADO_CIVIL                1115624 non-null  object
#  51  CD_COR_RACA                    1115624 non-null  object
#  52  DS_COR_RACA                    1115624 non-null  object
#  53  CD_OCUPACAO                    1115624 non-null  object
#  54  DS_OCUPACAO                    1115624 non-null  object
#  55  VR_DESPESA_MAX_CAMPANHA        1115624 non-null  object
#  56  CD_SIT_TOT_TURNO               1115624 non-null  object
#  57  DS_SIT_TOT_TURNO               1115624 non-null  object
#  58  ST_REELEICAO                   1115624 non-null  object
#  59  ST_DECLARAR_BENS               1115624 non-null  object
#  60  NR_PROTOCOLO_CANDIDATURA       1115624 non-null  object
#  61  NR_PROCESSO                    1115624 non-null  object
#  62  CD_SITUACAO_CANDIDATO_PLEITO   1115624 non-null  object
#  63  DS_SITUACAO_CANDIDATO_PLEITO   1115624 non-null  object
#  64  CD_SITUACAO_CANDIDATO_URNA     1115624 non-null  object
#  65  DS_SITUACAO_CANDIDATO_URNA     1115624 non-null  object
#  66  ST_CANDIDATO_INSERIDO_URNA     1115624 non-null  object
#  67  NM_TIPO_DESTINACAO_VOTOS       1115624 non-null  object
#  68  CD_SITUACAO_CANDIDATO_TOT      1115624 non-null  object
#  69  DS_SITUACAO_CANDIDATO_TOT      1115624 non-null  object
#  70  ST_PREST_CONTAS                1115624 non-null  object
#  71  ST_SUBSTITUIDO                 1115624 non-null  object
#  72  SQ_SUBSTITUIDO                 1115624 non-null  object
#  73  SQ_ORDEM_SUPLENCIA             1115624 non-null  object
#  74  DT_ACEITE_CANDIDATURA          1115624 non-null  object
# dtypes: object(75)
# memory usage: 638.4+ MB

# %%
# Filtrando df_tse para manter apenas as colunas desejadas
colunas_desejadas = ['DT_ELEICAO','NR_CPF_CANDIDATO','TP_ABRANGENCIA','SG_UF','DS_CARGO','DS_SITUACAO_CANDIDATURA',
                        'DS_DETALHE_SITUACAO_CAND','TP_AGREMIACAO','SG_PARTIDO', 'NR_IDADE_DATA_POSSE', 'DS_GENERO',
                       'DS_GRAU_INSTRUCAO', 'DS_ESTADO_CIVIL', 'DS_COR_RACA', 'DS_OCUPACAO', 'ST_REELEICAO', 
                        'ST_DECLARAR_BENS','VR_DESPESA_MAX_CAMPANHA']
df_tse = df_tse[colunas_desejadas]
df_tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115624 entries, 0 to 1115623
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   DT_ELEICAO                1115624 non-null  object
#  1   NR_CPF_CANDIDATO          1115624 non-null  object
#  2   TP_ABRANGENCIA            1115624 non-null  object
#  3   SG_UF                     1115624 non-null  object
#  4   DS_CARGO                  1115624 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   1115624 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  1115624 non-null  object
#  7   TP_AGREMIACAO             1115624 non-null  object
#  8   SG_PARTIDO                1115624 non-null  object
#  9   NR_IDADE_DATA_POSSE       1115624 non-null  object
#  10  DS_GENERO                 1115624 non-null  object
#  11  DS_GRAU_INSTRUCAO         1115624 non-null  object
#  12  DS_ESTADO_CIVIL           1115624 non-null  object
#  13  DS_COR_RACA               1115624 non-null  object
#  14  DS_OCUPACAO               1115624 non-null  object
#  15  ST_REELEICAO              1115624 non-null  object
#  16  ST_DECLARAR_BENS          1115624 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   1115624 non-null  object
# dtypes: object(18)
# memory usage: 153.2+ MB

# %%
# Ajustando os tipos de dados em df_tse
df_tse['DT_ELEICAO'] = pd.to_datetime(df_tse['DT_ELEICAO'], format='%d/%m/%Y')
df_tse['NR_IDADE_DATA_POSSE'] = df_tse['NR_IDADE_DATA_POSSE'].astype(float)
df_tse['VR_DESPESA_MAX_CAMPANHA'] = df_tse['VR_DESPESA_MAX_CAMPANHA'].astype(float)
df_tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115624 entries, 0 to 1115623
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   DT_ELEICAO                1115624 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          1115624 non-null  object
#  2   TP_ABRANGENCIA            1115624 non-null  object
#  3   SG_UF                     1115624 non-null  object
#  4   DS_CARGO                  1115624 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   1115624 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  1115624 non-null  object
#  7   TP_AGREMIACAO             1115624 non-null  object
#  8   SG_PARTIDO                1115624 non-null  object
#  9   NR_IDADE_DATA_POSSE       1115099 non-null  float64
#  10  DS_GENERO                 1115624 non-null  object
#  11  DS_GRAU_INSTRUCAO         1115624 non-null  object
#  12  DS_ESTADO_CIVIL           1115624 non-null  object
#  13  DS_COR_RACA               1115624 non-null  object
#  14  DS_OCUPACAO               1115624 non-null  object
#  15  ST_REELEICAO              1115624 non-null  object
#  16  ST_DECLARAR_BENS          1115624 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   1115624 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(15)
# memory usage: 153.2+ MB

# %%
# Substituindo valores indesejados e tratando valores faltantes
df_tse.replace([-1, -3, -4, "-1", "-4", "NÃO DIVULGÁVEL", "#NE", "#NULO","NE", "NULO"], np.nan, inplace=True)
df_tse = df_tse.dropna(axis=0)
df_tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1075257 entries, 0 to 1115623
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   DT_ELEICAO                1075257 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          1075257 non-null  object
#  2   TP_ABRANGENCIA            1075257 non-null  object
#  3   SG_UF                     1075257 non-null  object
#  4   DS_CARGO                  1075257 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   1075257 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  1075257 non-null  object
#  7   TP_AGREMIACAO             1075257 non-null  object
#  8   SG_PARTIDO                1075257 non-null  object
#  9   NR_IDADE_DATA_POSSE       1075257 non-null  float64
#  10  DS_GENERO                 1075257 non-null  object
#  11  DS_GRAU_INSTRUCAO         1075257 non-null  object
#  12  DS_ESTADO_CIVIL           1075257 non-null  object
#  13  DS_COR_RACA               1075257 non-null  object
#  14  DS_OCUPACAO               1075257 non-null  object
#  15  ST_REELEICAO              1075257 non-null  object
#  16  ST_DECLARAR_BENS          1075257 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   1075257 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(15)
# memory usage: 155.9+ MB

# %%
df_tse
# Out:
#         DT_ELEICAO NR_CPF_CANDIDATO TP_ABRANGENCIA SG_UF           DS_CARGO  \
# 0       2016-10-02      95168559387      MUNICIPAL    MA           VEREADOR
# 1       2016-10-02      84681454320      MUNICIPAL    PI           VEREADOR
# 2       2016-10-02      53564901353      MUNICIPAL    PI           VEREADOR
# 3       2016-10-02      75498189320      MUNICIPAL    PI           VEREADOR
# 4       2016-10-02       1575640880      MUNICIPAL    SP           VEREADOR
# ...            ...              ...            ...   ...                ...
# 1115619 2022-10-02      58412689887       ESTADUAL    SP   DEPUTADO FEDERAL
# 1115620 2022-10-02      87060027491       ESTADUAL    AL   DEPUTADO FEDERAL
# 1115621 2022-10-02      66188660149       ESTADUAL    MS  DEPUTADO ESTADUAL
# 1115622 2022-10-02        474146260       ESTADUAL    AC  DEPUTADO ESTADUAL
# 1115623 2022-10-02      80148654215       ESTADUAL    AM  DEPUTADO ESTADUAL
#
#         DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 0                          APTO                 DEFERIDO        COLIGAÇÃO
# 1                          APTO                 DEFERIDO        COLIGAÇÃO
# 2                          APTO                 DEFERIDO        COLIGAÇÃO
# 3                          APTO                 DEFERIDO        COLIGAÇÃO
# 4                        INAPTO               INDEFERIDO        COLIGAÇÃO
# ...                         ...                      ...              ...
# 1115619                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115620                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115621                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115622                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115623                    APTO                 DEFERIDO  PARTIDO ISOLADO
#
#            SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO  \
# 0                 PTB                 73.0   FEMININO
# 1                 DEM                 37.0  MASCULINO
# 2                  PP                 42.0  MASCULINO
# 3                  PP                 39.0  MASCULINO
# 4                  PP                 56.0  MASCULINO
# ...               ...                  ...        ...
# 1115619          AGIR                 72.0  MASCULINO
# 1115620  REPUBLICANOS                 48.0   FEMININO
# 1115621           PSD                 48.0   FEMININO
# 1115622          PROS                 45.0  MASCULINO
# 1115623           MDB                 38.0  MASCULINO
#
#                      DS_GRAU_INSTRUCAO DS_ESTADO_CIVIL DS_COR_RACA  \
# 0        ENSINO FUNDAMENTAL INCOMPLETO       CASADO(A)       PARDA
# 1                    SUPERIOR COMPLETO       CASADO(A)       PARDA
# 2                    SUPERIOR COMPLETO     SOLTEIRO(A)       PARDA
# 3              ENSINO MÉDIO INCOMPLETO     SOLTEIRO(A)       PARDA
# 4        ENSINO FUNDAMENTAL INCOMPLETO   DIVORCIADO(A)      BRANCA
# ...                                ...             ...         ...
# 1115619          ENSINO MÉDIO COMPLETO       CASADO(A)      BRANCA
# 1115620              SUPERIOR COMPLETO       CASADO(A)      BRANCA
# 1115621          ENSINO MÉDIO COMPLETO     SOLTEIRO(A)       PARDA
# 1115622    ENSINO FUNDAMENTAL COMPLETO     SOLTEIRO(A)       PRETA
# 1115623              SUPERIOR COMPLETO     SOLTEIRO(A)       PARDA
#
#                                    DS_OCUPACAO ST_REELEICAO ST_DECLARAR_BENS  \
# 0                            TRABALHADOR RURAL            N                N
# 1              PROFESSOR DE ENSINO FUNDAMENTAL            N                S
# 2              PROFESSOR DE ENSINO FUNDAMENTAL            N                N
# 3                                       OUTROS            N                N
# 4                                       OUTROS            N                S
# ...                                        ...          ...              ...
# 1115619  AUXILIAR DE ESCRITÓRIO E ASSEMELHADOS            N                N
# 1115620                              PSICÓLOGO            N                S
# 1115621                                 OUTROS            N                S
# 1115622                                 OUTROS            N                N
# 1115623                             ENGENHEIRO            N                S
#
#          VR_DESPESA_MAX_CAMPANHA
# 0                       10803.91
# 1                       32499.97
# 2                       32499.97
# 3                       32499.97
# 4                       10803.91
# ...                          ...
# 1115619               3176572.53
# 1115620               3176572.53
# 1115621               1270629.01
# 1115622               1270629.01
# 1115623               1270629.01
#
# [1075257 rows x 18 columns]

# %%
# Preenchendo zeros à esquerda na coluna cpf, para obter 11 caracteres
df_tse['NR_CPF_CANDIDATO'] = df_tse['NR_CPF_CANDIDATO'].str.zfill(11)
df_tse
# Out:
#         DT_ELEICAO NR_CPF_CANDIDATO TP_ABRANGENCIA SG_UF           DS_CARGO  \
# 0       2016-10-02      95168559387      MUNICIPAL    MA           VEREADOR
# 1       2016-10-02      84681454320      MUNICIPAL    PI           VEREADOR
# 2       2016-10-02      53564901353      MUNICIPAL    PI           VEREADOR
# 3       2016-10-02      75498189320      MUNICIPAL    PI           VEREADOR
# 4       2016-10-02      01575640880      MUNICIPAL    SP           VEREADOR
# ...            ...              ...            ...   ...                ...
# 1115619 2022-10-02      58412689887       ESTADUAL    SP   DEPUTADO FEDERAL
# 1115620 2022-10-02      87060027491       ESTADUAL    AL   DEPUTADO FEDERAL
# 1115621 2022-10-02      66188660149       ESTADUAL    MS  DEPUTADO ESTADUAL
# 1115622 2022-10-02      00474146260       ESTADUAL    AC  DEPUTADO ESTADUAL
# 1115623 2022-10-02      80148654215       ESTADUAL    AM  DEPUTADO ESTADUAL
#
#         DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 0                          APTO                 DEFERIDO        COLIGAÇÃO
# 1                          APTO                 DEFERIDO        COLIGAÇÃO
# 2                          APTO                 DEFERIDO        COLIGAÇÃO
# 3                          APTO                 DEFERIDO        COLIGAÇÃO
# 4                        INAPTO               INDEFERIDO        COLIGAÇÃO
# ...                         ...                      ...              ...
# 1115619                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115620                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115621                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115622                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 1115623                    APTO                 DEFERIDO  PARTIDO ISOLADO
#
#            SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO  \
# 0                 PTB                 73.0   FEMININO
# 1                 DEM                 37.0  MASCULINO
# 2                  PP                 42.0  MASCULINO
# 3                  PP                 39.0  MASCULINO
# 4                  PP                 56.0  MASCULINO
# ...               ...                  ...        ...
# 1115619          AGIR                 72.0  MASCULINO
# 1115620  REPUBLICANOS                 48.0   FEMININO
# 1115621           PSD                 48.0   FEMININO
# 1115622          PROS                 45.0  MASCULINO
# 1115623           MDB                 38.0  MASCULINO
#
#                      DS_GRAU_INSTRUCAO DS_ESTADO_CIVIL DS_COR_RACA  \
# 0        ENSINO FUNDAMENTAL INCOMPLETO       CASADO(A)       PARDA
# 1                    SUPERIOR COMPLETO       CASADO(A)       PARDA
# 2                    SUPERIOR COMPLETO     SOLTEIRO(A)       PARDA
# 3              ENSINO MÉDIO INCOMPLETO     SOLTEIRO(A)       PARDA
# 4        ENSINO FUNDAMENTAL INCOMPLETO   DIVORCIADO(A)      BRANCA
# ...                                ...             ...         ...
# 1115619          ENSINO MÉDIO COMPLETO       CASADO(A)      BRANCA
# 1115620              SUPERIOR COMPLETO       CASADO(A)      BRANCA
# 1115621          ENSINO MÉDIO COMPLETO     SOLTEIRO(A)       PARDA
# 1115622    ENSINO FUNDAMENTAL COMPLETO     SOLTEIRO(A)       PRETA
# 1115623              SUPERIOR COMPLETO     SOLTEIRO(A)       PARDA
#
#                                    DS_OCUPACAO ST_REELEICAO ST_DECLARAR_BENS  \
# 0                            TRABALHADOR RURAL            N                N
# 1              PROFESSOR DE ENSINO FUNDAMENTAL            N                S
# 2              PROFESSOR DE ENSINO FUNDAMENTAL            N                N
# 3                                       OUTROS            N                N
# 4                                       OUTROS            N                S
# ...                                        ...          ...              ...
# 1115619  AUXILIAR DE ESCRITÓRIO E ASSEMELHADOS            N                N
# 1115620                              PSICÓLOGO            N                S
# 1115621                                 OUTROS            N                S
# 1115622                                 OUTROS            N                N
# 1115623                             ENGENHEIRO            N                S
#
#          VR_DESPESA_MAX_CAMPANHA
# 0                       10803.91
# 1                       32499.97
# 2                       32499.97
# 3                       32499.97
# 4                       10803.91
# ...                          ...
# 1115619               3176572.53
# 1115620               3176572.53
# 1115621               1270629.01
# 1115622               1270629.01
# 1115623               1270629.01
#
# [1075257 rows x 18 columns]

# %%
# Identificando duplicidade de cpf
contagem_valores = df_tse['NR_CPF_CANDIDATO'].value_counts()
contagem_valores
# Out:
# 03031482840    6
# 44828624953    6
# 61496880382    6
# 05161704497    6
# 06512097572    6
#               ..
# 48550116734    1
# 44340994855    1
# 25281917234    1
# 63533804372    1
# 80148654215    1
# Name: NR_CPF_CANDIDATO, Length: 882582, dtype: int64

# %%
# Filtrando cpf especifico para analise
df_cpf_especifico_duplicado = df_tse[df_tse['NR_CPF_CANDIDATO'] == '03031482840']
df_cpf_especifico_duplicado
# Out:
#         DT_ELEICAO NR_CPF_CANDIDATO TP_ABRANGENCIA SG_UF           DS_CARGO  \
# 123524  2016-10-02      03031482840      MUNICIPAL    SP           PREFEITO
# 424117  2016-10-30      03031482840      MUNICIPAL    SP           PREFEITO
# 498488  2018-10-07      03031482840       ESTADUAL    SP  DEPUTADO ESTADUAL
# 626895  2020-11-29      03031482840      MUNICIPAL    SP           PREFEITO
# 1072370 2020-11-15      03031482840      MUNICIPAL    SP           PREFEITO
# 1110758 2022-10-02      03031482840       ESTADUAL    SP  DEPUTADO ESTADUAL
#
#         DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 123524                     APTO                 DEFERIDO        COLIGAÇÃO
# 424117                     APTO                 DEFERIDO        COLIGAÇÃO
# 498488                     APTO                 DEFERIDO  PARTIDO ISOLADO
# 626895                     APTO                 DEFERIDO        COLIGAÇÃO
# 1072370                    APTO                 DEFERIDO        COLIGAÇÃO
# 1110758                    APTO                 DEFERIDO  PARTIDO ISOLADO
#
#         SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO  DS_GRAU_INSTRUCAO  \
# 123524          PV                 55.0  MASCULINO  SUPERIOR COMPLETO
# 424117          PV                 55.0  MASCULINO  SUPERIOR COMPLETO
# 498488        PODE                 57.0  MASCULINO  SUPERIOR COMPLETO
# 626895         DEM                 59.0  MASCULINO  SUPERIOR COMPLETO
# 1072370        DEM                 59.0  MASCULINO  SUPERIOR COMPLETO
# 1110758       PODE                 61.0  MASCULINO  SUPERIOR COMPLETO
#
#         DS_ESTADO_CIVIL DS_COR_RACA DS_OCUPACAO ST_REELEICAO ST_DECLARAR_BENS  \
# 123524        CASADO(A)      BRANCA      MÉDICO            N                S
# 424117        CASADO(A)      BRANCA      MÉDICO            N                S
# 498488        CASADO(A)      BRANCA      MÉDICO            N                S
# 626895        CASADO(A)      BRANCA      MÉDICO            N                S
# 1072370       CASADO(A)      BRANCA      MÉDICO            N                S
# 1110758       CASADO(A)      BRANCA      MÉDICO            N                S
#
#          VR_DESPESA_MAX_CAMPANHA
# 123524                 533142.74
# 424117                 159942.82
# 498488                1000000.00
# 626895                 242941.15
# 1072370                607352.88
# 1110758               1270629.01

# %%
# Ordenando pela coluna data
df_tse = df_tse.sort_values(by='DT_ELEICAO', ascending=True)

# %%
# Visualizando novamente para conferencia
df_tse = df_tse.drop_duplicates(subset='NR_CPF_CANDIDATO', keep='last')
df_cpf_especifico = df_tse[df_tse['NR_CPF_CANDIDATO'] == '03031482840']
df_cpf_especifico
# Out:
#         DT_ELEICAO NR_CPF_CANDIDATO TP_ABRANGENCIA SG_UF           DS_CARGO  \
# 1110758 2022-10-02      03031482840       ESTADUAL    SP  DEPUTADO ESTADUAL
#
#         DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 1110758                    APTO                 DEFERIDO  PARTIDO ISOLADO
#
#         SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO  DS_GRAU_INSTRUCAO  \
# 1110758       PODE                 61.0  MASCULINO  SUPERIOR COMPLETO
#
#         DS_ESTADO_CIVIL DS_COR_RACA DS_OCUPACAO ST_REELEICAO ST_DECLARAR_BENS  \
# 1110758       CASADO(A)      BRANCA      MÉDICO            N                S
#
#          VR_DESPESA_MAX_CAMPANHA
# 1110758               1270629.01

# %%
df_tse.reset_index(drop=True)
df_tse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882582 entries, 0 to 1092722
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_ELEICAO                882582 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          882582 non-null  object
#  2   TP_ABRANGENCIA            882582 non-null  object
#  3   SG_UF                     882582 non-null  object
#  4   DS_CARGO                  882582 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   882582 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  882582 non-null  object
#  7   TP_AGREMIACAO             882582 non-null  object
#  8   SG_PARTIDO                882582 non-null  object
#  9   NR_IDADE_DATA_POSSE       882582 non-null  float64
#  10  DS_GENERO                 882582 non-null  object
#  11  DS_GRAU_INSTRUCAO         882582 non-null  object
#  12  DS_ESTADO_CIVIL           882582 non-null  object
#  13  DS_COR_RACA               882582 non-null  object
#  14  DS_OCUPACAO               882582 non-null  object
#  15  ST_REELEICAO              882582 non-null  object
#  16  ST_DECLARAR_BENS          882582 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   882582 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(15)
# memory usage: 127.9+ MB

# %%
df_tse.reset_index(drop=True)
# Out:
#        DT_ELEICAO NR_CPF_CANDIDATO TP_ABRANGENCIA SG_UF    DS_CARGO  \
# 0      2016-10-02      95168559387      MUNICIPAL    MA    VEREADOR
# 1      2016-10-02      08363061719      MUNICIPAL    RJ    VEREADOR
# 2      2016-10-02      08335075670      MUNICIPAL    MG    VEREADOR
# 3      2016-10-02      02742879943      MUNICIPAL    MT    VEREADOR
# 4      2016-10-02      50485334968      MUNICIPAL    SC    VEREADOR
# ...           ...              ...            ...   ...         ...
# 882577 2022-10-30      41168720591       ESTADUAL    SE  GOVERNADOR
# 882578 2022-10-30      01094775029       ESTADUAL    RS  GOVERNADOR
# 882579 2022-10-30      70515182753       ESTADUAL    ES  GOVERNADOR
# 882580 2022-10-30      44250070263       ESTADUAL    AM  GOVERNADOR
# 882581 2022-10-30      08430005463       ESTADUAL    PB  GOVERNADOR
#
#        DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND TP_AGREMIACAO  \
# 0                         APTO                 DEFERIDO     COLIGAÇÃO
# 1                         APTO                 DEFERIDO     COLIGAÇÃO
# 2                         APTO                 DEFERIDO     COLIGAÇÃO
# 3                         APTO                 DEFERIDO     COLIGAÇÃO
# 4                         APTO                 DEFERIDO     COLIGAÇÃO
# ...                        ...                      ...           ...
# 882577                    APTO                 DEFERIDO     COLIGAÇÃO
# 882578                    APTO                 DEFERIDO     COLIGAÇÃO
# 882579                    APTO                 DEFERIDO     COLIGAÇÃO
# 882580                    APTO                 DEFERIDO     COLIGAÇÃO
# 882581                    APTO                 DEFERIDO     COLIGAÇÃO
#
#        SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO  \
# 0             PTB                 73.0   FEMININO
# 1              PP                 43.0   FEMININO
# 2        PATRIOTA                 29.0  MASCULINO
# 3            PSDB                 39.0  MASCULINO
# 4              PP                 55.0  MASCULINO
# ...           ...                  ...        ...
# 882577         PT                 54.0  MASCULINO
# 882578       PSDB                 37.0  MASCULINO
# 882579        PSB                 62.0  MASCULINO
# 882580      UNIÃO                 46.0  MASCULINO
# 882581       PSDB                 34.0  MASCULINO
#
#                     DS_GRAU_INSTRUCAO DS_ESTADO_CIVIL DS_COR_RACA  \
# 0       ENSINO FUNDAMENTAL INCOMPLETO       CASADO(A)       PARDA
# 1             ENSINO MÉDIO INCOMPLETO     SOLTEIRO(A)       PRETA
# 2               ENSINO MÉDIO COMPLETO     SOLTEIRO(A)      BRANCA
# 3                   SUPERIOR COMPLETO     SOLTEIRO(A)      BRANCA
# 4         ENSINO FUNDAMENTAL COMPLETO       CASADO(A)      BRANCA
# ...                               ...             ...         ...
# 882577              SUPERIOR COMPLETO       CASADO(A)      BRANCA
# 882578              SUPERIOR COMPLETO     SOLTEIRO(A)      BRANCA
# 882579              SUPERIOR COMPLETO       CASADO(A)      BRANCA
# 882580              SUPERIOR COMPLETO       CASADO(A)       PARDA
# 882581              SUPERIOR COMPLETO     SOLTEIRO(A)      BRANCA
#
#                                  DS_OCUPACAO ST_REELEICAO ST_DECLARAR_BENS  \
# 0                          TRABALHADOR RURAL            N                N
# 1                               DONA DE CASA            N                S
# 2                                     OUTROS            N                S
# 3                                 EMPRESÁRIO            N                S
# 4       APOSENTADO (EXCETO SERVIDOR PÚBLICO)            N                S
# ...                                      ...          ...              ...
# 882577                               SENADOR            N                S
# 882578                                OUTROS            S                S
# 882579                            GOVERNADOR            S                S
# 882580                            GOVERNADOR            S                S
# 882581                              DEPUTADO            N                S
#
#         VR_DESPESA_MAX_CAMPANHA
# 0                      10803.91
# 1                      33782.55
# 2                      39855.82
# 3                      29292.61
# 4                      10803.91
# ...                         ...
# 882577               3113041.08
# 882578               5781362.00
# 882579               3557761.23
# 882580               3557761.23
# 882581               3557761.23
#
# [882582 rows x 18 columns]

# %% [markdown]
# # Carregando dados Sapiens

# %%
# Tratamento de valores duplicados em df_sapiens
contagem_valores_unicos = df_sapiens['Pessoa_Doc'].value_counts()
contagem_valores_unicos.head(3)
# Out:
# 26994558000719    30
# 26994558000476    22
# 26994558000638    18
# Name: Pessoa_Doc, dtype: int64

# %%
# Exclusão de cnpj
df_sapiens = df_sapiens[df_sapiens['Pessoa_Doc'].str.len() == 11]
df_sapiens = df_sapiens.drop_duplicates(subset='Pessoa_Doc', keep='first')
df_sapiens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7288 entries, 2 to 12310
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pasta_NUP      7288 non-null   object
#  1   Tribunal_Nome  7288 non-null   object
#  2   Pessoa_Nome    7288 non-null   object
#  3   Pessoa_Doc     7288 non-null   object
# dtypes: object(4)
# memory usage: 284.7+ KB

# %%
# Dicionário de siglas UFs
tribunal_para_uf = {
    'TRIBUNAL SUPERIOR ELEITORAL': 'BR',
    'TRIBUNAL REGIONAL ELEITORAL DO RIO GRANDE DO SUL': 'RS',
    'TRIBUNAL REGIONAL ELEITORAL DE SÃO PAULO': 'SP',
    'TRIBUNAL REGIONAL ELEITORAL DO PARANÁ': 'PR',
    'TRIBUNAL REGIONAL ELEITORAL DO ESPÍRITO SANTO': 'ES',
    'TRIBUNAL REGIONAL ELEITORAL DE MINAS GERAIS': 'MG',
    'TRIBUNAL REGIONAL ELEITORAL DO RIO GRANDE DO NORTE': 'RN',
    'TRIBUNAL REGIONAL ELEITORAL DE SANTA CATARINA': 'SC',
    'TRIBUNAL REGIONAL ELEITORAL DE GOIÁS': 'GO',
    'TRIBUNAL REGIONAL ELEITORAL DO RIO DE JANEIRO': 'RJ',
    'TRIBUNAL REGIONAL ELEITORAL DE SERGIPE': 'SE',
    'TRIBUNAL REGIONAL ELEITORAL DO PARÁ': 'PA',
    'TRIBUNAL REGIONAL ELEITORAL DO CEARÁ': 'CE',
    'TRIBUNAL REGIONAL ELEITORAL DA BAHIA': 'BA',
    'TRIBUNAL REGIONAL ELEITORAL DO MARANHÃO': 'MA',
    'TRIBUNAL REGIONAL ELEITORAL DO PERNAMBUCO': 'PE',
    'TRIBUNAL REGIONAL ELEITORAL DO DISTRITO FEDERAL E TERRITÓRIOS': 'DF',
    'TRIBUNAL REGIONAL ELEITORAL DA PARAÍBA': 'PB',
    'TRIBUNAL REGIONAL ELEITORAL DO AMAZONAS': 'AM',
    'TRIBUNAL REGIONAL ELEITORAL DO MATO GROSSO': 'MT',
    'TRIBUNAL REGIONAL ELEITORAL DO MATO GROSSO DO SUL': 'MS',
    'TRIBUNAL REGIONAL ELEITORAL DE ALAGOAS': 'AL',
    'TRIBUNAL REGIONAL ELEITORAL DO AMAPÁ': 'AP',
    'TRIBUNAL REGIONAL ELEITORAL DO TOCANTINS': 'TO',
    'TRIBUNAL REGIONAL ELEITORAL DE RORAIMA': 'RR',
    'TRIBUNAL REGIONAL ELEITORAL DO PIAUÍ': 'PI',
    'TRIBUNAL REGIONAL ELEITORAL DE RONDÔNIA': 'RO',
    'TRIBUNAL REGIONAL ELEITORAL DO ACRE': 'AC'
}
# Substituindo os valores na coluna com o dicionário
df_sapiens['Tribunal_Nome'] = df_sapiens['Tribunal_Nome'].map(tribunal_para_uf)

# %%
df_sapiens.drop(['Pasta_NUP'], axis=1, inplace=True)
df_sapiens.drop(['Pessoa_Nome'], axis=1, inplace=True)
df_sapiens.rename(columns={'Pessoa_Doc': 'NR_CPF_CANDIDATO'}, inplace=True)
df_sapiens.rename(columns={'Tribunal_Nome': 'SG_UF'}, inplace=True)

# %%
df_sapiens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7288 entries, 2 to 12310
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SG_UF             7288 non-null   object
#  1   NR_CPF_CANDIDATO  7288 non-null   object
# dtypes: object(2)
# memory usage: 170.8+ KB

# %% [markdown]
# ### Criando nova base

# %%
# juntando pela coluna de cpf
df_final = df_tse.merge(df_sapiens[['NR_CPF_CANDIDATO']], on='NR_CPF_CANDIDATO', how='left', indicator=True)

# Criando a coluna 'devedor' pelo indicador '_merge'
df_final['DEVEDOR'] = (df_final['_merge'] == 'both').astype(int)

# excluindo o indicador
df_final.drop(columns='_merge', inplace=True)

df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882582 entries, 0 to 882581
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_ELEICAO                882582 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          882582 non-null  object
#  2   TP_ABRANGENCIA            882582 non-null  object
#  3   SG_UF                     882582 non-null  object
#  4   DS_CARGO                  882582 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   882582 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  882582 non-null  object
#  7   TP_AGREMIACAO             882582 non-null  object
#  8   SG_PARTIDO                882582 non-null  object
#  9   NR_IDADE_DATA_POSSE       882582 non-null  float64
#  10  DS_GENERO                 882582 non-null  object
#  11  DS_GRAU_INSTRUCAO         882582 non-null  object
#  12  DS_ESTADO_CIVIL           882582 non-null  object
#  13  DS_COR_RACA               882582 non-null  object
#  14  DS_OCUPACAO               882582 non-null  object
#  15  ST_REELEICAO              882582 non-null  object
#  16  ST_DECLARAR_BENS          882582 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   882582 non-null  float64
#  18  DEVEDOR                   882582 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), object(15)
# memory usage: 131.3+ MB

# %%
# Contando o número de devedores e não devedores
contagem_devedores = df_final['DEVEDOR'].value_counts()
contagem_devedores
# Out:
# 0    876737
# 1      5845
# Name: DEVEDOR, dtype: int64

# %%
# Verificando se existem valores nulos
print(f"Existem {df_tse['NR_CPF_CANDIDATO'].isnull().sum()} valores nulos no df do TSE")
print(f"Existem {df_sapiens['NR_CPF_CANDIDATO'].isnull().sum()} valores nulos no df do Sapiens")

# Identificando CPFs presentes no df_sapiens que não estão no df_tse
valores_nao_encontrados = len(df_sapiens.loc[~df_sapiens['NR_CPF_CANDIDATO'].
                                             isin(df_tse['NR_CPF_CANDIDATO']), 'NR_CPF_CANDIDATO'])

print(f"Existem {valores_nao_encontrados} valores exclusivos no df do Sapiens.")
# Out:
# Existem 0 valores nulos no df do TSE
# Existem 0 valores nulos no df do Sapiens
# Existem 1443 valores exclusivos no df do Sapiens.

# %%
# Reinicializando o índice
df_tse = df_final.reset_index(drop=True)

# %%
# Criando uma nova coluna 'FAIXA_ETARIA' para categorizar as idades
faixa_etaria = [0, 35, 59, 110]
faixas_etarias = ['Jovem', 'Adulto', 'Idoso']

df_final['FAIXA_ETARIA'] = pd.cut(df_final['NR_IDADE_DATA_POSSE'], bins=faixa_etaria, labels=faixas_etarias, right=False)

df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882582 entries, 0 to 882581
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_ELEICAO                882582 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          882582 non-null  object
#  2   TP_ABRANGENCIA            882582 non-null  object
#  3   SG_UF                     882582 non-null  object
#  4   DS_CARGO                  882582 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   882582 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  882582 non-null  object
#  7   TP_AGREMIACAO             882582 non-null  object
#  8   SG_PARTIDO                882582 non-null  object
#  9   NR_IDADE_DATA_POSSE       882582 non-null  float64
#  10  DS_GENERO                 882582 non-null  object
#  11  DS_GRAU_INSTRUCAO         882582 non-null  object
#  12  DS_ESTADO_CIVIL           882582 non-null  object
#  13  DS_COR_RACA               882582 non-null  object
#  14  DS_OCUPACAO               882582 non-null  object
#  15  ST_REELEICAO              882582 non-null  object
#  16  ST_DECLARAR_BENS          882582 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   882582 non-null  float64
#  18  DEVEDOR                   882582 non-null  int32
#  19  FAIXA_ETARIA              882573 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(2), int32(1), object(15)
# memory usage: 132.1+ MB

# %%
# Verificando se há valores nulos na coluna 'FAIXA_ETARIA' para entendimento
nulos_faixa_etaria = df_final[df_final['FAIXA_ETARIA'].isnull()]
nulos_faixa_etaria
# Out:
#        DT_ELEICAO NR_CPF_CANDIDATO TP_ABRANGENCIA SG_UF           DS_CARGO  \
# 51508  2016-10-02      78684242653      MUNICIPAL    MG           VEREADOR
# 118571 2016-10-02      78961890204      MUNICIPAL    RR           VEREADOR
# 146552 2016-10-02      79590586287      MUNICIPAL    AM           VEREADOR
# 158578 2016-10-02      99019272420      MUNICIPAL    PE           VEREADOR
# 263468 2016-10-02      64157520220      MUNICIPAL    AM           VEREADOR
# 320780 2018-10-07      01752740297       ESTADUAL    PA  DEPUTADO ESTADUAL
# 392211 2020-11-15      62841106500      MUNICIPAL    BA           VEREADOR
# 579464 2020-11-15      31698391870      MUNICIPAL    BA           VEREADOR
# 696401 2020-11-15      36538515134      MUNICIPAL    MS           VEREADOR
#
#        DS_SITUACAO_CANDIDATURA DS_DETALHE_SITUACAO_CAND    TP_AGREMIACAO  \
# 51508                   INAPTO                 RENÚNCIA        COLIGAÇÃO
# 118571                    APTO                 DEFERIDO        COLIGAÇÃO
# 146552                    APTO                 DEFERIDO        COLIGAÇÃO
# 158578                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 263468                    APTO                 DEFERIDO        COLIGAÇÃO
# 320780                  INAPTO               INDEFERIDO        COLIGAÇÃO
# 392211                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 579464                    APTO                 DEFERIDO  PARTIDO ISOLADO
# 696401                    APTO                 DEFERIDO  PARTIDO ISOLADO
#
#        SG_PARTIDO  NR_IDADE_DATA_POSSE  DS_GENERO  \
# 51508          PR                999.0  MASCULINO
# 118571        PSD                999.0  MASCULINO
# 146552        PSB                999.0  MASCULINO
# 158578        PCB                999.0  MASCULINO
# 263468       PSDB                999.0   FEMININO
# 320780        PRB                825.0  MASCULINO
# 392211       PODE                999.0   FEMININO
# 579464        PSB                120.0   FEMININO
# 696401        PSD                116.0  MASCULINO
#
#                     DS_GRAU_INSTRUCAO DS_ESTADO_CIVIL DS_COR_RACA  \
# 51508   ENSINO FUNDAMENTAL INCOMPLETO     SOLTEIRO(A)       PARDA
# 118571        ENSINO MÉDIO INCOMPLETO       CASADO(A)       PARDA
# 146552  ENSINO FUNDAMENTAL INCOMPLETO       CASADO(A)       PARDA
# 158578          ENSINO MÉDIO COMPLETO     SOLTEIRO(A)       PARDA
# 263468              SUPERIOR COMPLETO     SOLTEIRO(A)       PARDA
# 320780              SUPERIOR COMPLETO   DIVORCIADO(A)      BRANCA
# 392211  ENSINO FUNDAMENTAL INCOMPLETO   DIVORCIADO(A)       PARDA
# 579464                   LÊ E ESCREVE     SOLTEIRO(A)       PARDA
# 696401  ENSINO FUNDAMENTAL INCOMPLETO   DIVORCIADO(A)      BRANCA
#
#                                          DS_OCUPACAO ST_REELEICAO  \
# 51508   MOTORISTA DE VEÍCULOS DE TRANSPORTE DE CARGA            N
# 118571                                        OUTROS            N
# 146552                                    AGRICULTOR            N
# 158578                                        OUTROS            N
# 263468                     SERVIDOR PÚBLICO ESTADUAL            N
# 320780                                        OUTROS            N
# 392211                                    AGRICULTOR            N
# 579464                                    AGRICULTOR            N
# 696401                                    AGRICULTOR            S
#
#        ST_DECLARAR_BENS  VR_DESPESA_MAX_CAMPANHA  DEVEDOR FAIXA_ETARIA
# 51508                 S                 10803.91        0          NaN
# 118571                N                343902.96        0          NaN
# 146552                N                 17445.96        0          NaN
# 158578                S                121699.88        0          NaN
# 263468                S                 10803.91        0          NaN
# 320780                N               1000000.00        0          NaN
# 392211                N                 12307.75        0          NaN
# 579464                S                 12307.75        0          NaN
# 696401                S                 12307.75        0          NaN

# %%
# Removendo entradas com valores nulos na coluna 'FAIXA_ETARIA'
df_final = df_final.dropna(subset=['FAIXA_ETARIA'])
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882573 entries, 0 to 882581
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_ELEICAO                882573 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          882573 non-null  object
#  2   TP_ABRANGENCIA            882573 non-null  object
#  3   SG_UF                     882573 non-null  object
#  4   DS_CARGO                  882573 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   882573 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  882573 non-null  object
#  7   TP_AGREMIACAO             882573 non-null  object
#  8   SG_PARTIDO                882573 non-null  object
#  9   NR_IDADE_DATA_POSSE       882573 non-null  float64
#  10  DS_GENERO                 882573 non-null  object
#  11  DS_GRAU_INSTRUCAO         882573 non-null  object
#  12  DS_ESTADO_CIVIL           882573 non-null  object
#  13  DS_COR_RACA               882573 non-null  object
#  14  DS_OCUPACAO               882573 non-null  object
#  15  ST_REELEICAO              882573 non-null  object
#  16  ST_DECLARAR_BENS          882573 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   882573 non-null  float64
#  18  DEVEDOR                   882573 non-null  int32
#  19  FAIXA_ETARIA              882573 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(2), int32(1), object(15)
# memory usage: 132.1+ MB

# %%
# Criando uma coluna 'FAIXA_DESPESA' para categorizar os valores
valores_despesas = [0, 50000, 100000, 500000, 1000000, 10000000, 50000000, 100000000, 1000000000]
faixas_despesa = ['Minimo', 'Baixo', 'Razoavel', 'Médio', 'Elevado', 'Alto', 'Altissimo', 'Perigoso']

df_final['FAIXA_DESPESA'] = pd.cut(df_final['VR_DESPESA_MAX_CAMPANHA'], bins=valores_despesas, labels=faixas_despesa, right=False)
df_final['FAIXA_DESPESA'].value_counts()
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882573 entries, 0 to 882581
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DT_ELEICAO                882573 non-null  datetime64[ns]
#  1   NR_CPF_CANDIDATO          882573 non-null  object
#  2   TP_ABRANGENCIA            882573 non-null  object
#  3   SG_UF                     882573 non-null  object
#  4   DS_CARGO                  882573 non-null  object
#  5   DS_SITUACAO_CANDIDATURA   882573 non-null  object
#  6   DS_DETALHE_SITUACAO_CAND  882573 non-null  object
#  7   TP_AGREMIACAO             882573 non-null  object
#  8   SG_PARTIDO                882573 non-null  object
#  9   NR_IDADE_DATA_POSSE       882573 non-null  float64
#  10  DS_GENERO                 882573 non-null  object
#  11  DS_GRAU_INSTRUCAO         882573 non-null  object
#  12  DS_ESTADO_CIVIL           882573 non-null  object
#  13  DS_COR_RACA               882573 non-null  object
#  14  DS_OCUPACAO               882573 non-null  object
#  15  ST_REELEICAO              882573 non-null  object
#  16  ST_DECLARAR_BENS          882573 non-null  object
#  17  VR_DESPESA_MAX_CAMPANHA   882573 non-null  float64
#  18  DEVEDOR                   882573 non-null  int32
#  19  FAIXA_ETARIA              882573 non-null  category
#  20  FAIXA_DESPESA             882573 non-null  category
# dtypes: category(2), datetime64[ns](1), float64(2), int32(1), object(15)
# memory usage: 133.0+ MB

# %%
df_final = df_final.drop('DT_ELEICAO', axis=1)
df_final = df_final.drop('NR_CPF_CANDIDATO', axis=1)
df_final = df_final.drop('NR_IDADE_DATA_POSSE', axis=1)
df_final = df_final.drop('VR_DESPESA_MAX_CAMPANHA', axis=1)
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882573 entries, 0 to 882581
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   TP_ABRANGENCIA            882573 non-null  object
#  1   SG_UF                     882573 non-null  object
#  2   DS_CARGO                  882573 non-null  object
#  3   DS_SITUACAO_CANDIDATURA   882573 non-null  object
#  4   DS_DETALHE_SITUACAO_CAND  882573 non-null  object
#  5   TP_AGREMIACAO             882573 non-null  object
#  6   SG_PARTIDO                882573 non-null  object
#  7   DS_GENERO                 882573 non-null  object
#  8   DS_GRAU_INSTRUCAO         882573 non-null  object
#  9   DS_ESTADO_CIVIL           882573 non-null  object
#  10  DS_COR_RACA               882573 non-null  object
#  11  DS_OCUPACAO               882573 non-null  object
#  12  ST_REELEICAO              882573 non-null  object
#  13  ST_DECLARAR_BENS          882573 non-null  object
#  14  DEVEDOR                   882573 non-null  int32
#  15  FAIXA_ETARIA              882573 non-null  category
#  16  FAIXA_DESPESA             882573 non-null  category
# dtypes: category(2), int32(1), object(14)
# memory usage: 106.1+ MB

# %%
df_final.to_parquet('df_final.parquet', index=False)
